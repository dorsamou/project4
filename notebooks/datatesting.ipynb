# %%
import sys
import os

sys.path.append(os.path.abspath('..'))
from src.data_formatting.formatting import BatteryStorageFormatter, BuildingLoadFormatter, PVGeneratorFormatter, combine_power
from src.config.config import DATASETS

# %%
# - KW = discharing, + KW = charging
battery_formatted = BatteryStorageFormatter("Trade Street Off-campus Microgrid/TradeStreetBattery.csv", rating_kw=1800)
df_batt = battery_formatted.run(save=False) 
df_batt.head(10)
# Out:
#              DateTime  RealPower
# 0 2016-10-25 00:00:00   -0.99425
# 1 2016-10-25 01:00:00   -0.99300
# 2 2016-10-25 02:00:00   -0.99225
# 3 2016-10-25 03:00:00   -0.98975
# 4 2016-10-25 04:00:00   -0.98625
# 5 2016-10-25 05:00:00   -0.98975
# 6 2016-10-25 06:00:00   -0.98925
# 7 2016-10-25 07:00:00   -0.99050
# 8 2016-10-25 08:00:00   -0.99125
# 9 2016-10-25 09:00:00   -0.99350

# %%
load_formatted = BuildingLoadFormatter("BuildingLoad/CenterHall.csv", cal_real=0.5, cal_reactive=1.0)
df_load = load_formatted.run(save=False) 
df_load.head(10)
# Out:
#              DateTime  RealPower  ReactivePower
# 0 2016-01-07 10:45:00    170.721         63.393
# 1 2016-01-07 11:00:00    182.143         71.259
# 2 2016-01-07 11:15:00    182.652         70.958
# 3 2016-01-07 11:30:00    177.763         68.534
# 4 2016-01-07 11:45:00    174.452         69.953
# 5 2016-01-07 12:00:00    173.569         70.313
# 6 2016-01-07 12:15:00    175.683         72.364
# 7 2016-01-07 12:30:00    180.513         78.072
# 8 2016-01-07 12:45:00    174.582         73.129
# 9 2016-01-07 13:00:00    168.523         70.999

# %%
pv_formatted = PVGeneratorFormatter("PVGenerator/BioEngineeringPV.csv")
df_pv = pv_formatted.run(save=False) 
df_pv.head(10)
# Out:
#              DateTime  RealPower
# 0 2015-01-21 08:45:00      5.273
# 1 2015-01-21 09:00:00      5.712
# 2 2015-01-21 09:15:00      7.303
# 3 2015-01-21 09:30:00      8.729
# 4 2015-01-21 09:45:00     13.882
# 5 2015-01-21 10:00:00     16.288
# 6 2015-01-21 10:15:00     16.729
# 7 2015-01-21 10:30:00     18.680
# 8 2015-01-21 10:45:00     19.710
# 9 2015-01-21 11:00:00     20.445

# %%
asset = "HopkinsBuilding"
data_set = DATASETS[asset]

if data_set["type"] == "load":
    formatter = BuildingLoadFormatter(
        data_set["filename"],
        cal_real=data_set["cal_real"],
        cal_reactive=data_set["cal_reactive"],
    )
    df = formatter.run(save=False)

elif data_set["type"] == "pv":
    formatter = PVGeneratorFormatter(data_set["filename"])
    df = formatter.run(save=False)

elif data_set["type"] == "battery":
    formatter = BatteryStorageFormatter(
        data_set["filename"],
        rating_kw=data_set["rating_kw"]
    )
    df = formatter.run(save=False)

elif data_set["type"] == "loadwev":
    formatter = BuildingLoadFormatter(
        data_set["filename"],
        cal_real=data_set["cal_real"],
        cal_reactive=data_set["cal_reactive"],
    )
    df = formatter.run(save=False)
    ev_asset = asset.replace("Building", "EV")
    ev_data_set = DATASETS[ev_asset]
    ev_formatter = BuildingLoadFormatter(
        ev_data_set["filename"],
        cal_real=ev_data_set["cal_real"],
        cal_reactive=ev_data_set["cal_reactive"],
    )
    ev_df = ev_formatter.run(save=False)

    df = combine_power(df, ev_df)


df.head()
# Out:
#              DateTime  RealPower
# 0 2019-04-01 00:00:00     50.676
# 1 2019-04-01 00:15:00     51.186
# 2 2019-04-01 00:30:00     51.873
# 3 2019-04-01 00:45:00     50.980
# 4 2019-04-01 01:00:00     51.912

# %%
for asset, data_info in DATASETS.items():
        if(asset == "BatteryStorage"):
            formatter = BatteryStorageFormatter(
                data_info["raw_filename"],
                rating_kw=data_info["rating_kw"]
            )
            df = formatter.run(save=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 7
#       2 if(asset == "BatteryStorage"):
#       3     formatter = BatteryStorageFormatter(
#       4         data_info["raw_filename"],
#       5         rating_kw=data_info["rating_kw"]
#       6     )
# ----> 7     df = formatter.run(save=True)
#
# File ~/Documents/DERConnect/project4/src/data_formatting/formatting.py:127, in BatteryStorageFormatter.run(self, save)
#     125 #DateTime, RealPower
#     126 if df.shape[1] < 2:
# --> 127     raise ValueError("Battery file expected to contain DateRime and RealPower columns")
#     128 power_col = df.columns[1]
#     129 timestamps = df[df.columns[0]]
#
# ValueError: Battery file expected to contain DateRime and RealPower columns

# %%
#read the csv first 10 rows in data/raw/BatteryStorage into a dataframe using pandas
import pandas as pd
sys.path.append(os.path.abspath('..'))
df_battery = pd.read_csv("data/raw/BatteryStorage.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 4
#       2 import pandas as pd
#       3 sys.path.append(os.path.abspath('..'))
# ----> 4 df_battery = pd.read_csv("data/raw/BatteryStorage.csv")
#
# ...
